# %% [markdown]
# # Lesson 1 #
# Big chimpin

# %%
print("Hello World")
# Out:
# Hello World

# %%
import matplotlib.pyplot as plt

y = [1, 1, 3, 3, 1]
x = [1, 2, 2, 1, 1]

plt.plot(x, y)

plt.ylabel("Big")
plt.xlabel("Shrimpin")
plt.title("Coca Cola Espuma")
# Out:
# Text(0.5, 1.0, 'Coca Cola Espuma')

# %%
snacks = [1, 4, 3, 7]
people = ["Xavier", "Ethan", "Carlos", "Shamour"]

plt.bar (people, snacks)

plt.xlabel ("Who")
plt.ylabel ("Sneks")
plt.title ("Whom got snaks")
# Out:
# Text(0.5, 1.0, 'Whom got snaks')

# %%
number = [1, 4, 3, 2]

plt.pie (number)
# Out:
# ([<matplotlib.patches.Wedge at 0x13e4fc070>,
# ...
#  [Text(1.0461621663333946, 0.3399186987098808, ''),
#   Text(-0.3399187231970732, 1.046162158377023, ''),
#   Text(-0.6465637025335373, -0.8899187482945414, ''),
#   Text(0.8899187785623722, -0.6465636608734332, '')])
